# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings
import seaborn as sns

# %% [markdown]
# ## read the data

# %%
df = pd.read_csv(r'D:\Priyanka\new_project_EDA\Automobile.csv')
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
# find out all column names available in the dataset

# %%
list[df.columns]
# Out:
# list[Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')]

# %%
# to see how loss is distributed along with the data
sns.distplot(df['normalized_losses'])
plt.show()
# Out:
# C:\Users\pbp1.ttl\AppData\Local\Temp\ipykernel_15280\686936543.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['normalized_losses'])

# %%
sns.distplot(df['normalized_losses'], kde=False, rug=True)
plt.show()
# Out:
# C:\Users\pbp1.ttl\AppData\Local\Temp\ipykernel_15280\1121016585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['normalized_losses'], kde=False, rug=True)

# %%
# we want to find out how the engine sizes changes with hp
sns.jointplot(data=df, x="engine_size", y="horsepower")

# %%
# Create a joint plot
sns.jointplot(data=df, x="engine_size", y="horsepower",kind = 'hex')

# %%
sns.pairplot(df[['normalized_losses', 'engine_size', 'horsepower']])

# %%
sns.stripplot(data = df,x = 'fuel_type', y ='horsepower', jitter = True)
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.swarmplot(data = df,x = 'fuel_type', y = 'horsepower')
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.boxplot(data = df,x = 'number_of_doors', y = 'horsepower',hue = 'fuel_type')
# Out:
# <Axes: xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.barplot(data = df,x = 'body_style', y = 'horsepower',hue = 'engine_location')
# Out:
# <Axes: xlabel='body_style', ylabel='horsepower'>

# %%
sns.countplot(data = df,x = 'body_style',hue = 'engine_location')
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.pointplot(data = df,x = 'fuel_system',y = 'horsepower',hue = 'number_of_doors')
# Out:
# <Axes: xlabel='fuel_system', ylabel='horsepower'>

# %%
sns.lmplot(x='horsepower', y ='peak_rpm', data= df, hue='fuel_type')
